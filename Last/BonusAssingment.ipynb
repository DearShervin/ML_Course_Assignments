# %% [markdown]
# <center style="font-size: 1rem; font-family: Times; color: aqua;">Last Bonus Assignment<center>
# <h1>Shervin Iranaghideh</h1>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics
import warnings
# warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("train.csv")
X = df[["battery_power", "blue", "clock_speed", "dual_sim", "fc", "four_g", "int_memory", "m_dep", "mobile_wt", "n_cores"]]
y = df[["price_range"]]
y = y.values.ravel()
X = preprocessing.StandardScaler().fit(X).transform(X.astype(float))

X_train, X_test, y_train, y_test = train_test_split( X, y, test_size=.2, random_state=29)
print ('Train set:', X_train.shape,  y_train.shape);
print ('Test set:', X_test.shape,  y_test.shape);

neigh = KNeighborsClassifier(n_neighbors= 5).fit(X_train, y_train)
yhat = neigh.predict(X_test)
print("Train set Accuracy: ", metrics.accuracy_score(y_train, neigh.predict(X_train)))
print("Test set Accuracy: ", metrics.accuracy_score(y_test, yhat))
# Out:
# Train set: (1600, 10) (1600,)
# Test set: (400, 10) (400,)
# Train set Accuracy:  0.515
# Test set Accuracy:  0.245

# %% [markdown]
# <h1><center style="font-size: 2rem; font-family: times;">Visualizing Data<center></h1>

# %%
plt.scatter(df[["battery_power"]], df[["int_memory"]], color="blue")
plt.xlabel("Battery Power")
plt.ylabel("Memory")
plt.show()

# %%
plt.scatter(df[["mobile_wt"]], df[["price_range"]], color="blue")
plt.xlabel("Mobile Wattage")
plt.ylabel("Price Range")
plt.show()
